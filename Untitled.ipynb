# %%
import pandas as pd
import numpy as np

# %%
match=pd.read_csv("matches.csv")
delivery=pd.read_csv("deliveries.csv")

# %%
match['method'].isnull().count()
# Out:
# np.int64(1095)

# %%
match
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %% [markdown]
# delivery.groupby(['match_id',"inning"]).sum()['total_runs']

# %%
total_score_df=delivery.groupby(['match_id',"inning"]).sum()['total_runs'].reset_index()

# %%
total_score_df['total_runs']=total_score_df['total_runs']+1

# %%
total_score_df=total_score_df[total_score_df['inning']==1]

# %%
match_df=match.merge(total_score_df[['match_id',"total_runs"]],left_on='id',right_on='match_id')

# %%
match.merge(total_score_df[['match_id',"inning"]],left_on='id',right_on='match_id')
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams= ['Mumbai Indians',
        'Kolkata Knight Riders',
        'Rajasthan Royals',
        'Chennai Super Kings',
        'Sunrisers Hyderabad',
        'Delhi Capitals',
        'Punjab Kings',
        'Lucknow Super Giants', 
        'Gujarat Titans',
        'Royal Challengers Bengaluru']

# %%
match_df['team1']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2']=match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1']=match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['team1']=match_df['team1'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
match_df['team2']=match_df['team2'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df['team1'].isin(teams)
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1090     True
# 1091     True
# 1092     True
# 1093     True
# 1094     True
# Name: team1, Length: 1095, dtype: bool

# %%
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 805 entries, 0 to 1094
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               805 non-null    int64
#  1   season           805 non-null    object
#  2   city             767 non-null    object
#  3   date             805 non-null    object
#  4   match_type       805 non-null    object
#  5   player_of_match  801 non-null    object
#  6   venue            805 non-null    object
#  7   team1            805 non-null    object
#  8   team2            805 non-null    object
#  9   toss_winner      805 non-null    object
#  10  toss_decision    805 non-null    object
#  11  winner           801 non-null    object
#  12  result           805 non-null    object
#  13  result_margin    792 non-null    float64
#  14  target_runs      803 non-null    float64
#  15  target_overs     803 non-null    float64
#  16  super_over       805 non-null    object
# ...

# %%
match_df=match_df[['match_id','city','winner','total_runs']]

# %%
delivery_df=match_df.merge(delivery,on='match_id')

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df.head(1)
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           223       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
#
#        bowler non_striker  batsman_runs  extra_runs  total_runs_y extras_type  \
# 124  AB Dinda    W Jaffer             1           0             1         NaN
#
#      is_wicket player_dismissed dismissal_kind fielder
# 124          0              NaN            NaN     NaN

# %%
delivery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92663 entries, 124 to 192241
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          92663 non-null  int64
#  1   city              88183 non-null  object
#  2   winner            92636 non-null  object
#  3   total_runs_x      92663 non-null  int64
#  4   inning            92663 non-null  int64
#  5   batting_team      92663 non-null  object
#  6   bowling_team      92663 non-null  object
#  7   over              92663 non-null  int64
#  8   ball              92663 non-null  int64
#  9   batter            92663 non-null  object
#  10  bowler            92663 non-null  object
#  11  non_striker       92663 non-null  object
#  12  batsman_runs      92663 non-null  int64
#  13  extra_runs        92663 non-null  int64
#  14  total_runs_y      92663 non-null  int64
#  15  extras_type       5002 non-null   object
# ...

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 192237   1426312    Chennai  Kolkata Knight Riders           114       2
# 192238   1426312    Chennai  Kolkata Knight Riders           114       2
# 192239   1426312    Chennai  Kolkata Knight Riders           114       2
# 192240   1426312    Chennai  Kolkata Knight Riders           114       2
# 192241   1426312    Chennai  Kolkata Knight Riders           114       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['current_score']
# Out:
# 124         1
# 125         2
# 126         2
# 127         3
# 128         4
#          ...
# 192237    110
# 192238    111
# 192239    112
# 192240    113
# 192241    114
# Name: current_score, Length: 92663, dtype: int64

# %%
delivery_df.tail(10)
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 192232   1426312  Chennai  Kolkata Knight Riders           114       2
# 192233   1426312  Chennai  Kolkata Knight Riders           114       2
# 192234   1426312  Chennai  Kolkata Knight Riders           114       2
# 192235   1426312  Chennai  Kolkata Knight Riders           114       2
# 192236   1426312  Chennai  Kolkata Knight Riders           114       2
# 192237   1426312  Chennai  Kolkata Knight Riders           114       2
# 192238   1426312  Chennai  Kolkata Knight Riders           114       2
# 192239   1426312  Chennai  Kolkata Knight Riders           114       2
# 192240   1426312  Chennai  Kolkata Knight Riders           114       2
# 192241   1426312  Chennai  Kolkata Knight Riders           114       2
#
#                  batting_team         bowling_team  over  ball   batter  ...  \
# 192232  Kolkata Knight Riders  Sunrisers Hyderabad     8     6  SS Iyer  ...
# ...

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df['over']=delivery_df['over']+1

# %%
delivery_df['over']==20
# Out:
# 124       False
# 125       False
# 126       False
# 127       False
# 128       False
#           ...
# 192237    False
# 192238    False
# 192239    False
# 192240    False
# 192241    False
# Name: over, Length: 92663, dtype: bool

# %%
delivery_df['balls_left']=126-(delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df['player_dismissed'].value_counts()
# Out:
# player_dismissed
# RG Sharma        91
# V Kohli          79
# DA Warner        72
# SV Samson        69
# S Dhawan         64
#                  ..
# JA Richardson     1
# MG Bracewell      1
# Kamran Khan       1
# T Henderson       1
# Mukesh Kumar      1
# Name: count, Length: 511, dtype: int64

# %%
delivery_df['player_dismissed'] = (
    pd.to_numeric(delivery_df['player_dismissed'], errors='coerce')
    .fillna(0)
    .astype(int)
)

# %%
delivery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125741 entries, 124 to 260919
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          125741 non-null  int64
#  1   city              119729 non-null  object
#  2   winner            125714 non-null  object
#  3   total_runs_x      125741 non-null  int64
#  4   inning            125741 non-null  int64
#  5   batting_team      125741 non-null  object
#  6   bowling_team      125741 non-null  object
#  7   over              125741 non-null  int64
#  8   ball              125741 non-null  int64
#  9   batter            125741 non-null  object
#  10  bowler            125741 non-null  object
#  11  non_striker       125741 non-null  object
#  12  batsman_runs      125741 non-null  int64
#  13  extra_runs        125741 non-null  int64
#  14  total_runs_y      125741 non-null  int64
#  15  extras_type       6748 non-null    object
# ...

# %%
delivery_df['player_dismissed'].value_counts()


delivery_df['is_wicket'].value_counts()
# Out:
# is_wicket
# 0    88024
# 1     4639
# Name: count, dtype: int64

# %%
delivery_df['player_dismissed'] = delivery_df['is_wicket'].astype(int)

# ✅ 2. Sort deliveries properly (important for correct cumsum)
delivery_df = delivery_df.sort_values(
    by=['match_id', 'inning', 'over', 'ball'],
    ignore_index=True
)

# ✅ 3. Compute cumulative wickets for each match and inning
delivery_df['cumulative_wickets'] = (
    delivery_df
    .groupby(['match_id', 'inning'])['player_dismissed']
    .transform('cumsum')
)

# ✅ 4. Calculate wickets remaining (max 10)
delivery_df['wickets'] = 10 - delivery_df['cumulative_wickets']

# %%
delivery_df['player_dismissed'] = (
    pd.to_numeric(delivery_df['player_dismissed'], errors='coerce')
    .fillna(0)
    .astype(int)
)
delivery_df = delivery_df.sort_values(['match_id', 'inning', 'over', 'ball'])
delivery_df['cumulative_wickets'] = (
    delivery_df.groupby(['match_id', 'inning'])['player_dismissed']
    .transform('cumsum')
)

# Calculate wickets remaining
delivery_df['wickets'] = 10 - delivery_df['cumulative_wickets']

# %%
delivery_df['cumulative_wickets'] = (
    delivery_df
    .groupby(['match_id', 'inning'], sort=False)['player_dismissed']
    .transform('cumsum')
)

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
# Out:
# C:\Users\Nikhil Gowda s\AppData\Local\Temp\ipykernel_9272\3308136775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 192237   1426312    Chennai  Kolkata Knight Riders           114       2
# 192238   1426312    Chennai  Kolkata Knight Riders           114       2
# 192239   1426312    Chennai  Kolkata Knight Riders           114       2
# 192240   1426312    Chennai  Kolkata Knight Riders           114       2
# 192241   1426312    Chennai  Kolkata Knight Riders           114       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df
# Out:
#        match_id       city                 winner  total_runs_x  inning  \
# 0        335982  Bangalore  Kolkata Knight Riders           223       2
# 1        335982  Bangalore  Kolkata Knight Riders           223       2
# 2        335982  Bangalore  Kolkata Knight Riders           223       2
# 3        335982  Bangalore  Kolkata Knight Riders           223       2
# 4        335982  Bangalore  Kolkata Knight Riders           223       2
# ...         ...        ...                    ...           ...     ...
# 92658   1426312    Chennai  Kolkata Knight Riders           114       2
# 92659   1426312    Chennai  Kolkata Knight Riders           114       2
# 92660   1426312    Chennai  Kolkata Knight Riders           114       2
# 92661   1426312    Chennai  Kolkata Knight Riders           114       2
# 92662   1426312    Chennai  Kolkata Knight Riders           114       2
#
#                       batting_team           bowling_team  over  ball  \
# ...

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#        match_id       city                 winner  total_runs_x  inning  \
# 0        335982  Bangalore  Kolkata Knight Riders           223       2
# 1        335982  Bangalore  Kolkata Knight Riders           223       2
# 2        335982  Bangalore  Kolkata Knight Riders           223       2
# 3        335982  Bangalore  Kolkata Knight Riders           223       2
# 4        335982  Bangalore  Kolkata Knight Riders           223       2
# ...         ...        ...                    ...           ...     ...
# 92658   1426312    Chennai  Kolkata Knight Riders           114       2
# 92659   1426312    Chennai  Kolkata Knight Riders           114       2
# 92660   1426312    Chennai  Kolkata Knight Riders           114       2
# 92661   1426312    Chennai  Kolkata Knight Riders           114       2
# 92662   1426312    Chennai  Kolkata Knight Riders           114       2
#
#                       batting_team           bowling_team  over  ball  \
# ...

# %%
final_df=delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df.dropna(inplace=True)

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                       batting_team                 bowling_team       city  \
# 76123               Delhi Capitals         Lucknow Super Giants    Lucknow
# 56586          Sunrisers Hyderabad        Kolkata Knight Riders  Abu Dhabi
# 17678             Delhi Daredevils               Mumbai Indians     Mumbai
# 41518          Sunrisers Hyderabad        Kolkata Knight Riders    Kolkata
# 66852        Kolkata Knight Riders  Royal Challengers Bangalore    Sharjah
# ...                            ...                          ...        ...
# 22632          Chennai Super Kings             Rajasthan Royals     Jaipur
# 24708          Chennai Super Kings               Mumbai Indians    Chennai
# 8196   Royal Challengers Bangalore          Chennai Super Kings     Durban
# 34869  Royal Challengers Bangalore        Kolkata Knight Riders    Kolkata
# 31388             Rajasthan Royals             Delhi Daredevils      Delhi
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])],remainder='passthrough')

# %%
2+2
# Out:
# 4

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[('step1',trf),('step2',LogisticRegression(solver='liblinear'))])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\Nikhil Gowda s\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8132218239745121

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,1426311,pipe)
temp_df
# Out:
# Target- 176
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 92477            1                8                0  64.6  35.4
# 92483            2                5                0  65.9  34.1
# 92489            3                6                0  64.9  35.1
# 92495            4                5                1  77.8  22.2
# 92501            5                4                0  79.2  20.8
# 92508            6               23                0  54.9  45.1
# 92514            7                4                0  57.2  42.8
# 92521            8               11                1  63.4  36.6
# 92527            9                4                1  77.8  22.2
# 92533           10                3                0  80.4  19.6
# 92539           11                6                0  79.8  20.2
# 92545           12                1                2  94.7   5.3
# 92551           13                4                0  95.2   4.8
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-176')

# %%
teams
# Out:
# ['Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Punjab Kings',
#  'Lucknow Super Giants',
#  'Gujarat Titans',
#  'Royal Challengers Bengaluru']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Delhi', 'Mumbai', 'Kolkata', 'Hyderabad', 'Chennai',
#        'Jaipur', 'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Visakhapatnam', 'Pune',
#        'Raipur', 'Ranchi', 'Abu Dhabi', nan, 'Bengaluru', 'Sharjah',
#        'Dubai', 'Navi Mumbai', 'Chandigarh', 'Lucknow', 'Guwahati',
#        'Dharamsala', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
